# %%
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')

# %run ImagePipeline(Version4).ipynb
# %run Model.ipynb

OUTPUT_CHANNELS = 3
LAMBDA = 100 # Generator l1 loss
loss_object = tf.keras.losses.BinaryCrossentropy(from_logits=True)
generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
generator = Generator()
discriminator = Discriminator()

## --------------------------------------------------------------------
# inp = train_image_load('2.jpg')
# inp = inp[0]
# re = inp[1]
# plt.subplot(1,3,1)
# plt.imshow(inp)
# down_model = downsample(3, 4)
# down_result = down_model(tf.expand_dims(inp, 0))
# print (down_result.shape)
# up_model = upsample(3, 4)
# up_result = up_model(down_result)
# print (up_result.shape)
# #tf.keras.utils.plot_model(generator, show_shapes=True, dpi=64)
# gen_output = generator(inp[tf.newaxis, ...], training=False)
# plt.subplot(1,3,2)
# plt.imshow(gen_output[0, ...])
# # tf.keras.utils.plot_model(discriminator, show_shapes=True, dpi=64)
# disc_out = discriminator([inp[tf.newaxis, ...], gen_output], training=False)
# plt.subplot(1,3,3)
# plt.imshow(disc_out[0, ..., -1], vmin=-20, vmax=20, cmap='RdBu_r')
# plt.colorbar()
# for example_input, example_target in train_dataset.take(1):
#     generate_images(generator, example_input, example_target)

# %%
fit(train_dataset, test_dataset, steps=300)
# Out:
# Step: 0k
# ..........Time taken for 100 steps: 190.35 sec
# Step: 0k
# ..........Time taken for 100 steps: 197.64 sec
# Step: 0k
# ..........

# %%
import os
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)
#checkpoint.save(file_prefix=checkpoint_prefix)

# %%
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
#inp, re = train_image_load('2.jpg')

# %%
#prediction = generator(inp[tf.newaxis, ...], training=False)

# %%
# plt.subplot(1,3,1)
# plt.imshow((denormalize(inp)))
# plt.subplot(1,3,2)
# plt.imshow((denormalize(re)))
# plt.subplot(1,3,3)
# plt.imshow(denormalize(prediction[0]))

# %%
# for gen_image, real_image in test_dataset.take(5):
#     generate_images(generator, gen_image, real_image)

# DONT FORGET, TENSORFLOW PREDICTIONS REQUIRE THE INPUT IMAGE TO HAVE A BATCH SIZE, EVEN IF IT IS ONLY INFERENCING ON ONE
# IMAGE !!
for gen_image, real_image in iter(test_dataset.take(5)):
    plt.subplot(1,3,1)
    plt.imshow(gen_image[0])
    plt.subplot(1,3,2)
    plt.imshow(real_image[0])
    plt.subplot(1,3,3)
    plt.imshow(generator.predict(gen_image)[0])
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 286ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 253ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
tf.keras.models.save_model(generator, "C:\\Users\\Ilyas\\Desktop\\Jsmodel_pre")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 18). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\Ilyas\Desktop\Jsmodel_pre\assets
# INFO:tensorflow:Assets written to: C:\Users\Ilyas\Desktop\Jsmodel_pre\assets
